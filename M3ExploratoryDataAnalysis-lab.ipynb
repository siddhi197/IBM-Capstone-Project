# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="380" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify the distribution of data in the dataset.
#
# -   Identify outliers in the dataset.
#
# -   Remove outliers from the dataset.
#
# -   Identify correlation between features in the dataset.

# %% [markdown]
# * * *

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %pip install seaborn
import seaborn as sns
import numpy as np

# %% [markdown]
# Load the dataset into a dataframe.

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %% [markdown]
# The functions below will download the dataset into your browser:

# %%
from pyodide.http import pyfetch

async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# %%
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv"

# %% [markdown]
# To obtain the dataset, utilize the download() function as defined above:

# %%
await download(file_path, "m2_survey_data.csv")
file_name="m2_survey_data.csv"

# %% [markdown]
# Utilize the Pandas method read_csv() to load the data into a dataframe.

# %%
df = pd.read_csv(file_name)
df.head()
# Out:
# 0     61000.0
# 1     95179.0
# 2     90000.0
# 3    455352.0
# 4     65277.0
# Name: ConvertedComp, dtype: float64

# %% [markdown]
# > Note: This version of the lab is working on JupyterLite, which requires the dataset to be downloaded to the interface.While working on the downloaded version of this notebook on their local machines(Jupyter Anaconda), the learners can simply **skip the steps above,** and simply use the URL directly in the `pandas.read_csv()` function. You can uncomment and run the statements in the cell below.

# %%
#df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here

plt.figure(figsize = (12, 6))

sns.distplot(df['ConvertedComp'], 'ConvertedComp', hist = False, kde = True)

plt.title('Distribution of Converted Annual Compensation', fontsize=16)
plt.xlabel('Converted Annual Compensation (USD)', fontsize=14)
plt.ylabel('Density', fontsize=14)

plt.show()
# Out:
# <ipython-input-7-ab05191e190c>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ConvertedComp'], 'ConvertedComp', hist = False, kde = True)

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here
plt.figure(figsize=(10, 6))
plt.hist(df['ConvertedComp'], bins=30, color='blue', edgecolor='black', alpha=0.7)

# Add titles and labels
plt.title('Histogram of Converted Compensation', fontsize=16)
plt.xlabel('Annual Salary (USD)', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Show the plot
plt.grid(axis='y')
plt.show()

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
print('Median ConvertedComp is: ',df['ConvertedComp'].median(), 'and median age is: ', df['Age'].median())
# Out:
# Median ConvertedComp is:  57745.0 and median age is:  29.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
print('Number of responders as a Man are: ', (df['Gender']== 'Man').sum())
# Out:
# Number of responders as a Man are:  10480

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
print('The median ConvertedComp of responders identified themselves only as a Woman: ', df.loc[df['Gender']=='Woman', 'ConvertedComp'].median())
# Out:
# The median ConvertedComp of responders identified themselves only as a Woman:  57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
df['Age'].describe()
# Out:
# count    11111.000000
# mean        30.778895
# std          7.393686
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here
df_new = df['Age'].dropna()

# Set figure size
plt.figure(figsize=(12, 6))

# Create histogram
count, bin_edges = np.histogram(df_new, bins=10)  # Specify number of bins

# Plot the histogram
plt.hist(df_new, bins=bin_edges, color='blue', edgecolor='black', alpha=0.7)

# Add titles and labels
plt.title('Histogram of Age', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Show the plot
plt.grid(axis='y')  # Optional: add grid lines for better readability
plt.show()

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here
plt.figure(figsize=(12, 6))

# Create the box plot
sns.boxplot(data=df, x='ConvertedComp')

# Add titles and labels
plt.title('Box Plot of Converted Compensation', fontsize=16)
plt.xlabel('Annual Salary (USD)', fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here
df_cleaned = df['ConvertedComp'].dropna()
q1, q3 = df_cleaned.quantile(0.25), df_cleaned.quantile(0.75)

IQR = q3 - q1

print('Inter Quartile Range is : ', IQR)
# Out:
# Inter Quartile Range is :  73132.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here
upperBound = q3 + (IQR * 1.5)
lowerBound = q1 - (IQR * 1.5)

print('Upper Bound:',upperBound, 'lowerBound:',lowerBound)
# Out:
# Upper Bound: 209698.0 lowerBound: -82830.0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here
outliers = df[(df['ConvertedComp'] < lowerBound) | (df['ConvertedComp'] > upperBound)]

outliers.shape[0]
# Out:
# 879

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here
df_no_outliers = df[(df['ConvertedComp']>=lowerBound) & (df['ConvertedComp']<=upperBound)]
df_no_outliers.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp  WorkWeekHrs   CodeRevHrs  \
# count   9703.000000  9.703000e+03    9703.000000  9664.000000  7612.000000
# mean   12501.007317  7.241139e+05   59883.208389    41.864782     4.737455
# std     7235.627217  7.186806e+06   43394.336755    24.613489     4.420472
# min        4.000000  0.000000e+00       0.000000     3.000000     0.000000
# 25%     6237.000000  2.000000e+04   24060.000000    40.000000     2.000000
# 50%    12571.000000  6.300000e+04   52704.000000    40.000000     4.000000
# 75%    18787.500000  1.150000e+05   85574.500000    42.000000     5.000000
# max    25141.000000  3.900000e+08  209356.000000  1012.000000    99.000000
#
#                Age
# count  9493.000000
# mean     30.695860
# std       7.346625
# min      16.000000
# 25%      25.000000
# 50%      29.000000
# 75%      34.000000
# max      99.000000

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here
numeric_df = df.select_dtypes(include=[np.number])

correlation_matrix = numeric_df.corr()

age_correlation = correlation_matrix['Age']
age_correlation
corr_matrix = df.select_dtypes(include=np.number).corr()
corr_matrix['Age']
# Out:
# Respondent       0.004041
# CompTotal        0.006970
# ConvertedComp    0.105386
# WorkWeekHrs      0.036518
# CodeRevHrs      -0.020469
# Age              1.000000
# Name: Age, dtype: float64

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).

# %% [markdown]
# <!--## Change Log

# %% [markdown]
# <!--| Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |--!>
